# %%
# Nome: Felipe Barroso de Castro
# RA: 2311292
# Curso: Engenharia de Software

import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.6
k = 5

#k_values = list(range(n+1))
prob5 = binom.pmf(k,n,p)
prob_acumulado5 = binom.cdf(5,n,p)
print (prob5)
print (prob_acumulado5)

k_values = list(range(n+1))
dist = [binom.pmf(r, n, p) for r in k_values ] 
plt.bar(k_values, dist) 
plt.ylabel('Probabilidade')
plt.title('Distribuição das probabilidades')
plt.show()
# Out:
# 0.20065812479999992
# 0.3668967424000001
